# %%
using Plots; pyplot()
# Out:
# Plots.PyPlotBackend()

# %%
irrad = vec([2.76828671       2.14824224       1.99969101       1.95315135       1.93789709       1.93277109       1.93101931       1.93041348       1.93020236       1.93012834]);
x = 1:length(irrad);

# %%
plot(x, irrad)
xlabel!("z")
ylabel!("irrad")
yaxis!(0,3)
# Out:
# <img src="data:image/png;base64,..." />
